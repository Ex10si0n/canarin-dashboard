# %%
!
# Out:
#                              ,Φ▒╖
#                           ╓Φ╣╬╬╬╬╣▌╦
#                        ╔Φ╣╬╬╬╬╬╬╬╬╬╬╬▓╦
#                    ,╔Φ╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╣▓
#                 ,╔▓╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╣▓▓▓╣                          ex10si0n@Neuron.local
#              ,▄▓╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╣▓▓▓▓▓▓▓                          ---------------------
#           ,#▓╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╣▓▓▓▓▓▓▓▓▓▓       ,φ▓φ,              OS: macOS 11.4 20F71 arm64
#        ,#▓╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╣▓▓▓▓▓▓▓▓▓▓▓▓▓    ,@▓╬╬╬╬╬▓▒,           Host: MacBookAir (Apple Silicon M1)
#     ,@▓╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╣▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓ ╓Φ▓╬╬╬╬╬╬╬╬╬╬╬▓▒µ        Kernel: 20.5.0
#    ║▓╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬▓▓▓▓▓▓▓▓▓▓▓▓▓▓╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬▒       Shell: fish
#    ║▓▓▓▓╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬▓▓▓█▓▓▓▓╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬▒       Resolution: 1440x900
#    ║▓▓▓▓▓▓▓╣╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬█▓╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬▒       DE: Aqua
#    ║▓▓▓▓▓▓▓▓▓▓╣╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬╬▒       WM: Quartz Compositor
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

# Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Configure Visualization
# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')
pylab.rcParams['figure.figsize'] = 8, 6

# %%
canarin_data = pd.read_csv("data.csv")
print('Canarin datasets:', canarin_data.shape)
# Out:
# Canarin datasets: (27957, 12)

# %%
canarin_data.head()
# Out:
#     Timestamp  Node             Datetime    GPS_Lat    GPS_Lng  GPS_Alt  PM1  \
# 0  1601503223  num0  2020-10-01 00:00:23  44.147877  12.235437        0  1.0
# 1  1601503285  num0  2020-10-01 00:01:25  44.147877  12.235437        0  2.0
# 2  1601503346  num0  2020-10-01 00:02:26  44.147877  12.235437        0  2.0
# 3  1601503408  num0  2020-10-01 00:03:28  44.147877  12.235437        0  1.0
# 4  1601503469  num0  2020-10-01 00:04:29  44.147877  12.235437        0  2.0
#
#    PM10  PM2_5  AirPressure  TemperatureExt  HumidityExt
# 0   2.0    2.0       1008.1            23.8         50.5
# 1   2.0    2.0       1008.2            23.7         50.5
# 2   2.0    2.0       1008.2            23.8         50.5
# 3   2.0    2.0       1008.1            23.8         50.5
# 4   2.0    2.0       1008.1            23.8         50.5

# %%
plt.plot(canarin_data.Timestamp, canarin_data.TemperatureExt)

# %%
plt.plot(canarin_data.Timestamp, canarin_data.HumidityExt)

# %%
plt.plot(canarin_data.Timestamp, canarin_data.AirPressure)

# %%
plt.plot(canarin_data.Timestamp, canarin_data.PM1)

# %%
plt.plot(canarin_data.Timestamp, canarin_data.PM10)

# %%
plt.plot(canarin_data.Timestamp, canarin_data.PM2_5)
